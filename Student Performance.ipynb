# %%
import pandas as pd
import numpy as np

# %%
sp=pd.read_csv(r'C:\Users\Lenovo\Downloads\StudentsPerformance (1).csv')
sp.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
sp.columns.tolist()
# Out:
# ['gender',
#  'race/ethnicity',
#  'parental level of education',
#  'lunch',
#  'test preparation course',
#  'math score',
#  'reading score',
#  'writing score']

# %%
sp.lunch.unique()
# Out:
# array(['standard', 'free/reduced'], dtype=object)

# %%
sp.gender.unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
sp.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=(15,5))
plt.subplots_adjust(left=0.2, bottom=0.1, right=0.8, top=0.9,
                      wspace=0.5, hspace=0.2)

plt.subplot(2, 2, 1)
sns.distplot(sp['math score'],kde=False,hist=True,bins=10,hist_kws=dict(edgecolor="k", linewidth=1))

plt.subplot(2, 2, 2)
sns.distplot(sp['reading score'],kde=False,hist=True,bins=10,hist_kws=dict(edgecolor="k", linewidth=1))

plt.subplot(2, 2, 3)
sns.distplot(sp['writing score'],kde=False,hist=True,bins=10,hist_kws=dict(edgecolor="k", linewidth=1))

plt.suptitle('Checking for mean', fontsize = 28)
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.subplots_adjust(left=0.2, bottom=0.1, right=0.8, top=0.9,
                      wspace=0.5, hspace=0.2)

plt.subplot(2, 2, 1)
sns.distplot(sp['math score'])

plt.subplot(2, 2, 2)
sns.distplot(sp['reading score'])

plt.subplot(2, 2, 3)
sns.distplot(sp['writing score'])

plt.suptitle('Checking for Skewness', fontsize = 28)
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.subplots_adjust(left=0.2, bottom=0.1, right=0.8, top=0.9,
                      wspace=0.5, hspace=0.2)
plt.subplot(1,3,1)
plt.title('Math Scores')
sns.barplot(x="gender", y="math score", data=sp)
plt.subplot(1,3,2)
plt.title('Reading Scores')
sns.barplot(x="gender", y="reading score", data=sp)
plt.subplot(1,3,3)
plt.title('Writing Scores')
sns.barplot(x="gender", y="writing score", data=sp)
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.subplots_adjust(left=0.01, bottom=0.1, right=0.8, top=0.99,
                      wspace=0.2, hspace=0.2)
plt.subplot(1,3,1)
plt.title('Math Scores')
sns.barplot(x="race/ethnicity", y="math score", data=sp)
plt.subplot(1,3,2)
plt.title('Reading Scores')
sns.barplot(x="race/ethnicity", y="reading score", data=sp)
plt.subplot(1,3,3)
plt.title('Writing Scores')
sns.barplot(x="race/ethnicity", y="writing score", data=sp)
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.subplots_adjust(left=0.01, bottom=0.1, right=0.99, top=0.9,
                      wspace=0.5, hspace=0.1)
plt.subplot(1,3,1)
plt.title('Math Scores')
sns.barplot(x="math score", y="parental level of education", data=sp)
plt.subplot(1,3,2)
plt.title('Reading Scores')
sns.barplot(x="reading score", y="parental level of education", data=sp)
plt.subplot(1,3,3)
plt.title('Writing Scores')
sns.barplot(x="writing score", y="parental level of education", data=sp)
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.subplots_adjust(left=0.01, bottom=0.1, right=0.8, top=0.99,
                      wspace=0.2, hspace=0.2)
plt.subplot(1,3,1)
plt.title('Math Scores')
sns.barplot(x="lunch", y="math score", data=sp)
plt.subplot(1,3,2)
plt.title('Reading Scores')
sns.barplot(x="lunch", y="reading score", data=sp)
plt.subplot(1,3,3)
plt.title('Writing Scores')
sns.barplot(x="lunch", y="writing score", data=sp)
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.subplots_adjust(left=0.01, bottom=0.1, right=0.8, top=0.99,
                      wspace=0.2, hspace=0.2)
plt.subplot(1,3,1)
plt.title('Math Scores')
sns.barplot(x="test preparation course", y="math score", data=sp)
plt.subplot(1,3,2)
plt.title('Reading Scores')
sns.barplot(x="test preparation course", y="reading score", data=sp)
plt.subplot(1,3,3)
plt.title('Writing Scores')
sns.barplot(x="test preparation course", y="writing score", data=sp)
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.subplots_adjust(left=0.01, bottom=0.1, right=0.8, top=0.99,
                      wspace=0.2, hspace=0.2)
plt.subplot(1,3,1)
plt.title('Math Scores')
sns.violinplot(y='math score',data=sp,color='r',linewidth=2)
plt.subplot(1,3,2)
plt.title('Reading Scores')
sns.violinplot(y='reading score',data=sp,color='b',linewidth=2)
plt.subplot(1,3,3)
plt.title('Writing Scores')
sns.violinplot(y='writing score',data=sp,color='y',linewidth=2)
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.title('Race Vs Gender',fontsize = 15)
sns.countplot(x="race/ethnicity", hue="gender", data=sp)
plt.show()

plt.figure(figsize=(20,5))
plt.title('Education Vs Gender',fontsize = 15)
sns.countplot(x="parental level of education", hue="gender", data=sp)
plt.show()

plt.figure(figsize=(20,5))
plt.title('Lunch Vs Gender',fontsize = 15)
sns.countplot(x="lunch", hue="gender", data=sp)
plt.show()

plt.figure(figsize=(20,5))
plt.title('Test Preparation Vs Gender',fontsize = 15)
sns.countplot(x="test preparation course", hue="gender", data=sp)
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.title('Education Vs Lunch',fontsize = 15)
sns.countplot(x="parental level of education", hue="lunch", data=sp)
plt.show()

plt.figure(figsize=(20,5))
plt.title('Race Vs Lunch',fontsize = 15)
sns.countplot(x="race/ethnicity", hue="lunch", data=sp)
plt.show()

plt.figure(figsize=(20,5))
plt.title('Test Preparation Vs Lunch',fontsize = 15)
sns.countplot(x="test preparation course", hue="lunch", data=sp)
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.title('Test Preparation Vs Education',fontsize = 15)
sns.countplot(x="parental level of education", hue="test preparation course", data=sp)
plt.show()

plt.figure(figsize=(20,5))
plt.title('Test Preparation Vs Race',fontsize = 15)
sns.countplot(x="race/ethnicity", hue="test preparation course", data=sp)
plt.show()

# %%
plt.figure(figsize=(20,5))
pr=pd.crosstab(sp['race/ethnicity'],sp['parental level of education'],normalize=0)
pr.plot.bar(stacked=True)
plt.title('Ethinicity Vs Parental Level of Education',fontsize = 15)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.subplots_adjust(left=0.05, bottom=0.1, right=0.95, top=0.9,
                      wspace=0.5, hspace=0.5)
plt.subplot(141)
plt.title('Gender',fontsize = 20)
sp['gender'].value_counts().plot.pie(autopct="%1.1f%%")

plt.subplot(142)
plt.title('Ethinicity',fontsize = 20)
sp['race/ethnicity'].value_counts().plot.pie(autopct="%1.1f%%")

plt.subplot(143)
plt.title('Parentel level of Education',fontsize = 20)
sp['parental level of education'].value_counts().plot.pie(autopct="%1.1f%%")

plt.subplot(144)
plt.title('Lunch',fontsize = 20)
sp['lunch'].value_counts().plot.pie(autopct="%1.1f%%")
plt.show()

# %%
sp['average score'] = (sp['math score'] + sp['reading score'] + sp['writing score'])/3

# %%
 sns.distplot(sp['average score'])

# %%
plt.figure(figsize=(20,5))
plt.subplots_adjust(left=0.01, bottom=0.01, right=0.8, top=0.99,
                      wspace=0.2, hspace=0.2)
plt.subplot(2,3,1)
sns.barplot(x="gender", y="average score", data=sp)
plt.subplot(2,3,2)
sns.barplot(x="race/ethnicity", y="average score", data=sp)
plt.subplot(2,3,3)
sns.barplot(x="parental level of education", y="average score", data=sp)
plt.subplot(2,3,4)
sns.barplot(x="lunch", y="average score", data=sp)
plt.subplot(2,3,5)
sns.barplot(x="test preparation course", y="average score", data=sp)

plt.show()

# %%
def determine_grade(scores):
    if scores >= 85 and scores <= 100:
        return 'Grade A'
    elif scores >= 70 and scores < 85:
        return 'Grade B'
    elif scores >= 55 and scores < 70:
        return 'Grade C'
    elif scores >= 35 and scores < 55:
        return 'Grade D'
    elif scores >= 0 and scores < 35:
        return 'Grade E'
    
sp['grades'] = sp['average score'].apply(determine_grade)

# %%
sp['grades'].value_counts().plot.pie(autopct="%1.1f%%")
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.title('Race Vs Grades',fontsize = 15)
sns.countplot(x="race/ethnicity", hue="grades", data=sp)
plt.show()

plt.figure(figsize=(20,5))
plt.title('Education Vs Grades',fontsize = 15)
sns.countplot(x="parental level of education", hue="grades", data=sp)
plt.show()

plt.figure(figsize=(20,5))
plt.title('Lunch Vs Grades',fontsize = 15)
sns.countplot(x="lunch", hue="grades", data=sp)
plt.show()

plt.figure(figsize=(20,5))
plt.title('Test Preparation Vs Grades',fontsize = 15)
sns.countplot(x="test preparation course", hue="grades", data=sp)
plt.show()

# %%
total_students = sp.shape[0]

students_score_more_than_50 = sp[sp['math score'] > 50].shape[0]
probability_of_students_scoring_more_than_50_in_maths = (students_score_more_than_50/total_students)*100
print("Probability of Students Scoring more than 50 marks in Maths :", probability_of_students_scoring_more_than_50_in_maths)


students_score_more_than_50 = sp[sp['writing score'] > 50].shape[0]
probability_of_students_scoring_more_than_50_in_reading = (students_score_more_than_50/total_students)*100
print("Probability of Students Scoring more than 50 marks in Reading :", probability_of_students_scoring_more_than_50_in_reading)


students_score_more_than_50 = sp[sp['writing score'] > 50].shape[0]
probability_of_students_scoring_more_than_50_in_writing = (students_score_more_than_50/total_students)*100
print("Probability of Students Scoring more than 50 marks in Writing :", probability_of_students_scoring_more_than_50_in_writing)



number_of_students_passing_in_all_subjects =  sp[(sp['math score'] > 90) &
                                                  (sp['writing score'] > 90) & 
                                                  (sp['reading score'] > 90)].shape[0]
probability_of_students_passing_in_all_the_subjects = (number_of_students_passing_in_all_subjects/total_students)*100
print("The Probability of Students Passing in all the Subjects is {0:.2f} %".format(probability_of_students_passing_in_all_the_subjects))

number_of_students_passing_overall = sp[sp['average score'] > 30].shape[0]
probability_of_students_passing_overall = (number_of_students_passing_overall/total_students)*100
print("probability_of_students_passing_overall :", probability_of_students_passing_overall)
# Out:
# Probability of Students Scoring more than 50 marks in Maths : 85.0
# Probability of Students Scoring more than 50 marks in Reading : 87.6
# Probability of Students Scoring more than 50 marks in Writing : 87.6
# The Probability of Students Passing in all the Subjects is 2.30 %
# probability_of_students_passing_overall : 99.0

# %%
np.random.seed(6)

# dataset of 1000 values
sample_math_marks = np.random.choice(a= sp['math score'], size=100)
print ("Sample mean for Math Scores:", sample_math_marks.mean() )  
print("Population mean for Math Scores:", sp['math score'].mean())

# dataset of 1000 values
sample_reading_marks = np.random.choice(a= sp['reading score'], size=100)
print ("\nSample mean for Reading Scores:", sample_reading_marks.mean() )
print("Population mean for Reading Scores:", sp['reading score'].mean())

# dataset of 1000 values
sample_writing_marks = np.random.choice(a= sp['writing score'], size=100)
print ("\nSample mean for Writing Scores:", sample_math_marks.mean() )
print("Population mean for Writing Scores:", sp['writing score'].mean())

# dataset of 1000 values
sample_average_marks = np.random.choice(a= sp['average score'], size=100)
print ("\nSample mean for average Scores:", sample_average_marks.mean() )
print("Population mean for average Scores:", sp['average score'].mean())
# Out:
# Sample mean for Math Scores: 63.12
# Population mean for Math Scores: 66.089
#
# Sample mean for Reading Scores: 68.5
# Population mean for Reading Scores: 69.169
#
# Sample mean for Writing Scores: 63.12
# Population mean for Writing Scores: 68.054
#
# Sample mean for average Scores: 69.48333333333333
# Population mean for average Scores: 67.77066666666664

# %%
sp[(sp['gender'] == 'female') &
     (sp['grades'] == 'Grade A')].head()
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 2    female        group B             master's degree  standard
# 6    female        group B                some college  standard
# 94   female        group B                some college  standard
# 102  female        group D          associate's degree  standard
# 106  female        group D             master's degree  standard
#
#     test preparation course  math score  reading score  writing score  \
# 2                      none          90             95             93
# 6                 completed          88             95             92
# 94                     none          79             86             92
# 102                    none          85             91             89
# 106                    none          87            100            100
#
#      average score   grades
# 2        92.666667  Grade A
# 6        91.666667  Grade A
# 94       85.666667  Grade A
# 102      88.333333  Grade A
# ...

# %%
sp.groupby(['gender']).agg(['min','median','max'])
# Out:
#        math score             reading score             writing score         \
#               min median  max           min median  max           min median
# gender
# female          0     65  100            17     73  100            10     74
# male           27     69  100            23     66  100            15     64
#
#             average score
#         max           min     median    max
# gender
# female  100           9.0  70.333333  100.0
# male    100          23.0  66.333333  100.0

# %%
sp[['lunch','gender','math score','writing score','reading score']].groupby(['lunch','gender']).agg('median')
# Out:
#                      math score  writing score  reading score
# lunch        gender
# free/reduced female        57.0           68.0           67.0
#              male          62.0           59.0           61.0
# standard     female        67.0           76.0           75.0
#              male          72.0           67.0           67.5

# %%
sp[['test preparation course',
      'gender',
      'math score',
      'writing score',
      'reading score']].groupby(['test preparation course','gender']).agg('median')
# Out:
#                                 math score  writing score  reading score
# test preparation course gender
# completed               female          67             79             78
#                         male            73             70             71
# none                    female          62             70             71
#                         male            67             60             63

# %%
sp[['race/ethnicity',
      'math score',
      'writing score',
      'reading score']].groupby(['race/ethnicity']).agg('median')
# Out:
#                 math score  writing score  reading score
# race/ethnicity
# group A               61.0           62.0           64.0
# group B               63.0           67.0           67.0
# group C               65.0           68.0           71.0
# group D               69.0           72.0           71.0
# group E               74.5           72.0           74.0
